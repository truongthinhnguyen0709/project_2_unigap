# %%
import pandas as pd

# %%
df_all_id = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/product_id_tiki.csv')

# %%
df_down_id= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/all_ids.csv')

# %%
df_all_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      200000 non-null  int64
# dtypes: int64(1)
# memory usage: 1.5 MB

# %%
df_down_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198917 entries, 0 to 198916
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      198917 non-null  int64
# dtypes: int64(1)
# memory usage: 1.5 MB

# %%
df_merge= pd.merge(df_all_id, df_down_id, on='id', how='outer', suffixes=('_left', '_right'))

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      200000 non-null  int64
# dtypes: int64(1)
# memory usage: 1.5 MB

# %%
id_tong = df_all_id['id'].tolist()
id_con = df_down_id['id'].tolist()

# 2. Tìm các ID có trong df_tong nhưng không có trong df_con
missing_ids = list(set(id_tong) - set(id_con))

# 3. Tạo DataFrame mới từ các ID bị thiếu
df_missing = pd.DataFrame({'id_thieu': missing_ids})

# %%
df_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1083 entries, 0 to 1082
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id_thieu  1083 non-null   int64
# dtypes: int64(1)
# memory usage: 8.6 KB

# %%
df_missing.to_csv('cac_id_bi_thieu.csv', index=False)
